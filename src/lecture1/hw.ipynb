# %%
using Pkg
Pkg.activate(".")

# function circlemat(n)
#     mat = zeros(n,n)
#     for i in 1:n
#         for j in 1:n
#             if ((i == j - 1 && j > 1) || (i == n && j == 1)) || ((i == j + 1 && j < n) || (i==1 && j == n))
#                 mat[i,j] = 1
#             end
#         end
#     end
#     return mat
# end
circlemat(n) = [((i == j - 1 && j > 1) || (i == n && j == 1)) || ((i == j + 1 && j < n) || (i==1 && j == n)) for i in 1:n, j in 1:n]


# polynomial(a, x) = sum(ia -> x^(ia[1]-1) * ia[2], enumerate(a))
function polynomial(a, x)
    powers = map(enumerate(a)) do (i, a_i)
        x^(i-1) * a_i
    end
    accumulator = sum(powers)
    return accumulator
end

A = circlemat(10)
arr = [1,1,1,1]
f = polynomial(arr, A)
println(f)

using GraphRecipes, Plots
graphplot(f)
# Out:
# [3 4 1 1 0 0 0 1 1 4; 4 3 4 1 1 0 0 0 1 1; 1 4 3 4 1 1 0 0 0 1; 1 1 4 3 4 1 1 0 0 0; 0 1 1 4 3 4 1 1 0 0; 0 0 1 1 4 3 4 1 1 0; 0 0 0 1 1 4 3 4 1 1; 1 0 0 0 1 1 4 3 4 1; 1 1 0 0 0 1 1 4 3 4; 4 1 1 0 0 0 1 1 4 3]
#   Activating environment at `~/repo/julia/src/lecture1/Project.toml`
